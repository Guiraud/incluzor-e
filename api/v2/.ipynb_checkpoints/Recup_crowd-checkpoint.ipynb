# %% [raw]
# import requests

# %%
import pandas as pd
from io import BytesIO
import requests
r = requests.get('https://docs.google.com/spreadsheets/d/e/2PACX-1vQhYVTsFV_Nsd2eKVWG8xfX3aJ5WQHvVBexaJQzq4BpUjFGk7aZImG02xNMOL7sb9HxrqV1kJ2Q6tYx/pub?output=csv')
data = r.content

# %%
df = pd.read_csv(BytesIO(data))

# %%
df.head()
# Out:
#   validation               sources  Unnamed: 2         masculin  \
# 0          V  leff,dicollecte,wiki         3.0  abstentionniste
# 1          D  leff,dicollecte,wiki         3.0          abuseur
# 2   F (Eléa)  leff,dicollecte,wiki         3.0          abyssin
# 3          V  leff,dicollecte,wiki         3.0       abyssinien
# 4          V  leff,dicollecte,wiki         3.0      académicien
#
#    masculin pluriel 1er féminin singulier 1er féminin pluriel  \
# 0  abstentionnistes       abstentionniste    abstentionnistes
# 1          abuseurs              abuseuse           abuseuses
# 2          abyssins              abyssine           abyssines
# 3       abyssiniens          abyssinienne       abyssiniennes
# 4      académiciens         académicienne      académiciennes
#
#   version inclusive 1 sg  incl 1er pluriel 2ème féminin singulier  \
# 0        abstentionniste  abstentionnistes                    NaN
# 1           abuseur·euse     abuseur·euses             abuseresse
# 2              abyssin·e        abyssin·es                    NaN
# 3          abyssinien·ne    abyssinien·nes                    NaN
# 4         académicien·ne   académicien·nes                    NaN
#
#   2ème féminin pluriel incl 2ème singulier incl 2ème pluriel  \
# 0                  NaN                 NaN               NaN
# 1          abuseresses      abuseur·eresse   abuseur·eresses
# 2                  NaN                 NaN               NaN
# 3                  NaN                 NaN               NaN
# 4                  NaN                 NaN               NaN
#
#   3ème féminin singulier 3ème féminin pluriel incl 3ème singulier  \
# 0                    NaN                  NaN                 NaN
# 1             abuseresse          abuseresses        abuseur·esse
# 2                    NaN                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
#
#   incl 3ème pluriel                                       commentaires
# 0               NaN                                                NaN
# 1    abuseurs·esses  la forme inclusive correcte est abuseur· .il f...
# 2               NaN  Le mot était écrit deux fois dans la colonne d...
# 3               NaN                                                NaN
# 4               NaN                                                NaN
