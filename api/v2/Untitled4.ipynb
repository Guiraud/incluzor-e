# %% [raw]
# import requests

# %%
import pandas as pd
from io import BytesIO
import requests
r = requests.get('https://docs.google.com/spreadsheets/d/e/2PACX-1vQhYVTsFV_Nsd2eKVWG8xfX3aJ5WQHvVBexaJQzq4BpUjFGk7aZImG02xNMOL7sb9HxrqV1kJ2Q6tYx/pub?output=csv')
data = r.content

# %%
df = pd.read_csv(BytesIO(data), index_col=0)

# %%
df.head()
# Out:
#                          sources  Unnamed: 2         masculin  \
# validation
# V           leff,dicollecte,wiki         3.0  abstentionniste
# D           leff,dicollecte,wiki         3.0          abuseur
# F (Eléa)    leff,dicollecte,wiki         3.0          abyssin
# V           leff,dicollecte,wiki         3.0       abyssinien
# V           leff,dicollecte,wiki         3.0      académicien
#
#             masculin pluriel 1er féminin singulier 1er féminin pluriel  \
# validation
# V           abstentionnistes       abstentionniste    abstentionnistes
# D                   abuseurs              abuseuse           abuseuses
# F (Eléa)            abyssins              abyssine           abyssines
# V                abyssiniens          abyssinienne       abyssiniennes
# V               académiciens         académicienne      académiciennes
#
#            version inclusive 1 sg  incl 1er pluriel 2ème féminin singulier  \
# validation
# V                 abstentionniste  abstentionnistes                    NaN
# D                    abuseur·euse     abuseur·euses             abuseresse
# F (Eléa)                abyssin·e        abyssin·es                    NaN
# V                   abyssinien·ne    abyssinien·nes                    NaN
# V                  académicien·ne   académicien·nes                    NaN
#
#            2ème féminin pluriel incl 2ème singulier incl 2ème pluriel  \
# validation
# V                           NaN                 NaN               NaN
# D                   abuseresses      abuseur·eresse   abuseur·eresses
# F (Eléa)                    NaN                 NaN               NaN
# V                           NaN                 NaN               NaN
# V                           NaN                 NaN               NaN
#
#            3ème féminin singulier 3ème féminin pluriel incl 3ème singulier  \
# validation
# V                             NaN                  NaN                 NaN
# D                      abuseresse          abuseresses        abuseur·esse
# F (Eléa)                      NaN                  NaN                 NaN
# V                             NaN                  NaN                 NaN
# V                             NaN                  NaN                 NaN
#
#            incl 3ème pluriel  \
# validation
# V                        NaN
# D             abuseurs·esses
# F (Eléa)                 NaN
# V                        NaN
# V                        NaN
#
#                                                  commentaires
# validation
# V                                                         NaN
# D           la forme inclusive correcte est abuseur· .il f...
# F (Eléa)    Le mot était écrit deux fois dans la colonne d...
# V                                                         NaN
# V                                                         NaN
